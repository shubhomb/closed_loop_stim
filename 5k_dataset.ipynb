# %%
import numpy as np
import pandas as pd
import logging
import pickle
import os 
import matplotlib.pyplot as plt

datadir = "5k_data_from_yuxuan/"
pattern_registrations = pickle.load(open(os.path.join(datadir, "pattern_registrations.pkl"), "rb"))
spkVecs = np.load(os.path.join(datadir, "spkVecs.npy"))

len(pattern_registrations)  # Number of sessions
# Out:
# 5000

# %%
pattern_registrations[3]
# Out:
# {'pattern_name': 1740,
#  'pattern_lambda': np.float64(0.6),
#  'pattern_flag_start_timestamp': np.int32(1087105),
#  'pattern_timing_index': 3,
#  'steps': [{'index': 0,
#    'channel_delays': [{'channel': 3, 'delay_mode': -1},
#     {'channel': 9, 'delay_mode': 0}],
#    'start_timestamp': 1090154},
#   {'index': 1, 'channel_delays': [], 'start_timestamp': 1091954},
#   {'index': 2,
#    'channel_delays': [{'channel': 22, 'delay_mode': 0},
#     {'channel': 63, 'delay_mode': 0},
#     {'channel': 28, 'delay_mode': 1},
#     {'channel': 52, 'delay_mode': 0},
#     {'channel': 9, 'delay_mode': -1},
#     {'channel': 19, 'delay_mode': 0}],
#    'start_timestamp': 1094264},
#   {'index': 3,
#    'channel_delays': [{'channel': 23, 'delay_mode': -1},
#     {'channel': 52, 'delay_mode': 0}],
#    'start_timestamp': 1096159},
#   {'index': 4, 'channel_delays': [], 'start_timestamp': 1097959},
#   {'index': 5, 'channel_delays': [], 'start_timestamp': 1099759},
#   {'index': 6, 'channel_delays': [], 'start_timestamp': 1101559},
#   {'index': 7, 'channel_delays': [], 'start_timestamp': 1103359},
#   {'index': 8, 'channel_delays': [], 'start_timestamp': 1105159},
#   {'index': 9,
#    'channel_delays': [{'channel': 15, 'delay_mode': 0},
#     {'channel': 61, 'delay_mode': 0}],
#    'start_timestamp': 1107675}]}
